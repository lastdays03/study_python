# %%
from urllib.request import urlopen # 서버 요청/응답 패키지
import bs4 # 파싱패키지

# %%
url = 'https://www.naver.com/robots.txt'
# url로 요청후 응답
html = urlopen(url)
print(html.read())
# Out:
# b'User-agent: *\nDisallow: /\nAllow : /$\nAllow : /.well-known/privacy-sandbox-attestations.json'

# %%
# 네이버 사이트의 기본 메뉴 문구 추출
url = 'https://www.naver.com'
# url로 요청후 응답
html = urlopen(url)
# 파서객체 생성 - bs4 객체로 변환
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 출력이 길어서 일부분만 출력
print(bs_obj.prettify()[:1944])
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
#       <meta content="https://www.naver.com/" name="twitter:url"/>
#       <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#       <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
#        <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification">
#         <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#         <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed">
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#          <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_251001.css" rel="stylesheet"/>
#          <link href="https://www.naver.com/" rel="canonical"/>
#          <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/>
#          <script>

# %%
test_menu = bs_obj.find('div',{'id':'wrap'})
# 출력이 길어서 일부분만 출력
print(test_menu.prettify()[1000:2950])
# Out:
# <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#         <input id="ie" name="ie" type="hidden" value="utf8"/>
#         <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#         <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#         <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#         <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#         <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#         <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#         <div class="search_input_box">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/>
#         </div>
#         <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit">
#          <span class="ico_btn_search_svg">
#           <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg">
#            <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z">
#            </path>
#           </svg>
#          </span>
#          <span class="blind">
#           검색
#          </span>
#         </button>
#        </fieldset>
#       </form>

# %%
# 네이버 뉴스 크롤링
# url은 기본 url 부터 사용
url = 'https://news.naver.com'
html = urlopen(url)

# %%
# html #<http.client.HTTPResponse at 0x1b6fa0cd0d0>
# html_text = html.read() # 바이너리 문자열로 반환
# # html_text

# %%
# bs4 객체 생성
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 출력이 길어서 일부분만 출력
print(bs_obj.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;

# %%
news_title = bs_obj.findAll('strong',{'class':'cnf_news_title'})
news_title2 = bs_obj.findAll('a',{'class':'cnf_news'})
news_titles = news_title + news_title2
# news_titles = bs_obj.findAll('strong', {'class': 'cnf_news_title'}) + bs_obj.findAll('a', {'class': 'cnf_news _cds_link _edi
# CSS 선택자 사용
# news_titles = bs_obj.select('strong.cnf_news_title, a.cnf_news')

# %%
len(news_titles)
# Out:
# 328

# %%
# 328개의 기사 중 상위 10개만 출력
news_titles[:10]
# Out:
# [<strong class="cnf_news_title">한미그룹 5년안에 매출 5조…비만·신약 청사진 나왔다</strong>,
#  <strong class="cnf_news_title">삼성SDI, 2차 ESS 입찰도 독주하나…'국내 생산·안전성' 모두 잡다</strong>,
#  <strong class="cnf_news_title">"실탄 10발씩 준비 맞나?" "네"…문상호 실토 뒤 고개 들곤 [현장영상]</strong>,
#  <strong class="cnf_news_title">정청래, 국힘 겨냥 "내란 비호정당에는 정당 해산뿐"</strong>,
#  <strong class="cnf_news_title">KT CEO 후보 숏리스트 누가 오를까</strong>,
#  <strong class="cnf_news_title">“서울은 ‘래미안’ 아니면 못짓고, 지방은 지을수록 손해” 건설업계도 양극화 [부동산360]</strong>,
#  <strong class="cnf_news_title">두피에 바르는 '탈모약' 대박 효과에 들썩…주가 '불기둥' [종목+]</strong>,
#  <strong class="cnf_news_title">쿠팡 이용자, 나흘 만에 감소 전환…이탈 본격화 조짐</strong>,
#  <strong class="cnf_news_title">'김건희에 로저비비에 가방 선물' 국민의힘 김기현 부인 특검 출석</strong>,
#  <strong class="cnf_news_title">계엄의 강, 국민의힘이 넘어야 의무의 길 [손기웅의 가야만 하는 길]</strong>]

# %%
print(type(news_title))
print(type(news_title2))
print(type(news_titles))
# Out:
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.ResultSet'>
# <class 'list'>

# %%
for title in news_titles[:10]:
    print(title.text)
# Out:
# 한미그룹 5년안에 매출 5조…비만·신약 청사진 나왔다
# 삼성SDI, 2차 ESS 입찰도 독주하나…'국내 생산·안전성' 모두 잡다
# "실탄 10발씩 준비 맞나?" "네"…문상호 실토 뒤 고개 들곤 [현장영상]
# 정청래, 국힘 겨냥 "내란 비호정당에는 정당 해산뿐"
# KT CEO 후보 숏리스트 누가 오를까
# “서울은 ‘래미안’ 아니면 못짓고, 지방은 지을수록 손해” 건설업계도 양극화 [부동산360]
# 두피에 바르는 '탈모약' 대박 효과에 들썩…주가 '불기둥' [종목+]
# 쿠팡 이용자, 나흘 만에 감소 전환…이탈 본격화 조짐
# '김건희에 로저비비에 가방 선물' 국민의힘 김기현 부인 특검 출석
# 계엄의 강, 국민의힘이 넘어야 의무의 길 [손기웅의 가야만 하는 길]

# %%
news_title[:10]
# Out:
# [<strong class="cnf_news_title">한미그룹 5년안에 매출 5조…비만·신약 청사진 나왔다</strong>,
#  <strong class="cnf_news_title">삼성SDI, 2차 ESS 입찰도 독주하나…'국내 생산·안전성' 모두 잡다</strong>,
#  <strong class="cnf_news_title">"실탄 10발씩 준비 맞나?" "네"…문상호 실토 뒤 고개 들곤 [현장영상]</strong>,
#  <strong class="cnf_news_title">정청래, 국힘 겨냥 "내란 비호정당에는 정당 해산뿐"</strong>,
#  <strong class="cnf_news_title">KT CEO 후보 숏리스트 누가 오를까</strong>,
#  <strong class="cnf_news_title">“서울은 ‘래미안’ 아니면 못짓고, 지방은 지을수록 손해” 건설업계도 양극화 [부동산360]</strong>,
#  <strong class="cnf_news_title">두피에 바르는 '탈모약' 대박 효과에 들썩…주가 '불기둥' [종목+]</strong>,
#  <strong class="cnf_news_title">쿠팡 이용자, 나흘 만에 감소 전환…이탈 본격화 조짐</strong>,
#  <strong class="cnf_news_title">'김건희에 로저비비에 가방 선물' 국민의힘 김기현 부인 특검 출석</strong>,
#  <strong class="cnf_news_title">계엄의 강, 국민의힘이 넘어야 의무의 길 [손기웅의 가야만 하는 길]</strong>]

# %%
news_title2
# Out:
# [<a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042418" onclick="nclk(event, 'home.editnfimg', '', '')">[인사이드 스토리]결국 실패한 롯데의 'HQ 실험'…이유는</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042424" onclick="nclk(event, 'home.editnfimg', '', '')">[기자수첩]약가인하, 제약사 어디로 내모나</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042419" onclick="nclk(event, 'home.editnfimg', '', '')">[인사이드 스토리]'중국산 김치'의 습격…흔들리는 '김치 종주국'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117494" onclick="nclk(event, 'home.editnfimg', '', '')">고환율 충격 어디까지?… 은행권, 건전성지표 3개월새 악화</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117568" onclick="nclk(event, 'home.editnfimg', '', '')">오스코텍, 정관 변경·이사 선임 무산… 임시주총 부결(상보)</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117550" onclick="nclk(event, 'home.editnfimg', '', '')">25세 연하 태국 아내, 외도 후 남편 가정폭력으로 신고… "재산 내놔"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467440" onclick="nclk(event, 'home.editnfimg', '', '')">추미애, 오세훈에 "퇴근 5시간…한강버스 생각에 눈 안치웠나"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467369" onclick="nclk(event, 'home.editnfimg', '', '')">'혐오 장사' 후원금 휩쓸던 그들…최근 행보 봤더니</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467405" onclick="nclk(event, 'home.editnfimg', '', '')">"빨래인 줄 알았더니 사람"…16층 난간에 매달린 절도범</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128147" onclick="nclk(event, 'home.editnfimg', '', '')">숨진 20대, 미성년 성범죄 전과…여중생 만남 전 흉기 구매(종합)</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128145" onclick="nclk(event, 'home.editnfimg', '', '')">추신수가 꺼리는 ‘추신수 거리’…부산 동구 난감하네</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128153" onclick="nclk(event, 'home.editnfimg', '', '')">김해 화목IC 내부토지(주택 등 2만여 평) 보상 제외 날벼락</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002400954" onclick="nclk(event, 'home.editnfimg', '', '')">"방어회 반값"…이마트, 고래잇 주말 행사 시작</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002401139" onclick="nclk(event, 'home.editnfimg', '', '')">SK그룹, 신상필벌·강소화 인사…반도체·AI 힘 실어</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002401224" onclick="nclk(event, 'home.editnfimg', '', '')">취준생 10명 중 7명 이상 "판교 밑으론 안 가"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002567712" onclick="nclk(event, 'home.editnfimg', '', '')">장경태 고소인 “비서관에게도 성폭행당했다”…추가 피해 주장</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002567738" onclick="nclk(event, 'home.editnfimg', '', '')">“누가 5만원을 뿌렸다” 서울 한복판에 돈다발…“줍고 난리 났다” 무슨 일</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002567376" onclick="nclk(event, 'home.editnfimg', '', '')">“하루 만에 800억 벌었다” 무려 ‘9연상’ 주식…부자 된 천일고속 대표, 정작 회사는 적자 [투자360]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220631" onclick="nclk(event, 'home.editnfimg', '', '')">[단독]'천스닥' 불붙나…코스닥 활성화 대책, 이르면 다음주 윤곽</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220617" onclick="nclk(event, 'home.editnfimg', '', '')">"가슴이 웅장해진다"…'30만원 돌파' 현대차 종토방은 잔칫집  [종목+]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220494" onclick="nclk(event, 'home.editnfimg', '', '')">"서울까지 27분이면 간다더니"…수원 주민들 뿔난 이유 [집코노미-집집폭폭]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015780696" onclick="nclk(event, 'home.editnfimg', '', '')">'불수능' 만점 광주서석고 최장우 군…"초·중등 독서경험 중요"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015780727" onclick="nclk(event, 'home.editnfimg', '', '')">"공부할 때 하고 쉴 때 쉰 게 비결" 수능 만점 이하진 학생</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015780113" onclick="nclk(event, 'home.editnfimg', '', '')">[샷!] "버스에서 누가 5만원권을 뿌렸다"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466174" onclick="nclk(event, 'home.editnfimg', '', '')">국무조정실 "헌법존중TF에 '계엄 가담' 자발적 신고하면 징계 면책"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466135" onclick="nclk(event, 'home.editnfimg', '', '')">"40일간 지옥 같았다"‥'신상 공개' 54살 김영우</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466041" onclick="nclk(event, 'home.editnfimg', '', '')">극우 집회서 마이크 잡고 윤어게인‥몇 달 뒤 충북대 학생회장?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033610" onclick="nclk(event, 'home.editnfimg', '', '')">쿠팡 유출 사태 ‘후폭풍’…이커머스 시장, 판도 변화 가능성은?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033599" onclick="nclk(event, 'home.editnfimg', '', '')">연말 송년회 '통풍 경보'…"겨울철 합병증 위험 커진다"[엑스레이]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033658" onclick="nclk(event, 'home.editnfimg', '', '')">동덕여대 '칼부림 예고' 범인은 10대女였다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287793" onclick="nclk(event, 'home.editnfimg', '', '')">"악! 악!" 빙판길 엉덩방아 '비명'...차 두고 '출근 지옥철' 우르르</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287720" onclick="nclk(event, 'home.editnfimg', '', '')">보리차와 뻥튀기로 버틴 9개월 아들 심정지...엄마는 먹던 분유 팔았다[뉴스속오늘]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287758" onclick="nclk(event, 'home.editnfimg', '', '')">"형부랑 단둘이 있기 어색해"...30분간 문 안 열어준 처제</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945122" onclick="nclk(event, 'home.editnfimg', '', '')">계엄 가담 공직자, 자수해서 광명?… 정부 “자발적 신고하면 징계 안해”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945121" onclick="nclk(event, 'home.editnfimg', '', '')">현대차, 장중 사상 최고가…휴머노이드·SW 전략에 주가 재평가 불붙었다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945109" onclick="nclk(event, 'home.editnfimg', '', '')">“어르신들, 독감보다 ‘이게’ 더 위험합니다”…65세 이상 입원환자 61% 차지</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005444741" onclick="nclk(event, 'home.editnfimg', '', '')">"감옥에 몰래 술 대주나"…尹, 비상계엄 1년 메시지에 쏟아진 비난</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005444681" onclick="nclk(event, 'home.editnfimg', '', '')">"누가 을지로에 5만원권 뿌렸다, 우선 줍자!"..SNS 글에 폭발적 반응, 가져도 될까?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005444636" onclick="nclk(event, 'home.editnfimg', '', '')">이경실 아들 손보승, '달걀 판매'로 영창위기..국방부 감찰실 조사 착수</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679543" onclick="nclk(event, 'home.editnfimg', '', '')">‘과속하면 넉달치 월급’… 인구 150만 도시의 ‘교통사망 0명’ 비결</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679574" onclick="nclk(event, 'home.editnfimg', '', '')">뜯은지 6개월 지나면 버려야…빨래 악취 원인은 ‘이것’ [알쓸톡]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679382" onclick="nclk(event, 'home.editnfimg', '', '')">“박나래, 술잔 던지고 폭언”…前매니저들 부동산 가압류-1억 손배소</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997678" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 세계 억만장자 수 2919명, 300여명 증가…한국선 7명 줄어든 31명</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997680" onclick="nclk(event, 'home.editnfimg', '', '')">‘산타 랠리’ 탄 삼성전자… ‘깜짝 실적’ 기대감에 5일째 강세</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997663" onclick="nclk(event, 'home.editnfimg', '', '')">자식버린 ‘패륜 부모’ 유족연금 못받는다…‘구하라법’ 내년 시행</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450455" onclick="nclk(event, 'home.editnfimg', '', '')">'로저비비에 의혹' 김기현 배우자 특검 출석…묵묵부답</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450383" onclick="nclk(event, 'home.editnfimg', '', '')">민주 '1인 1표제' 운명의 날…결과 어떻든 黨 '요동' 불가피?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450382" onclick="nclk(event, 'home.editnfimg', '', '')">'내란 몰이' 반격 나선 野…리더십 부재 속 '정국 반전' 미지수</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986714" onclick="nclk(event, 'home.editnfimg', '', '')">'불닭'이 연 K-볶음면⋯농심·CJ 가세하며 판 키운다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986704" onclick="nclk(event, 'home.editnfimg', '', '')">"불 꺼지고, 매대 비고"⋯홈플러스 '급속 악화' [현장]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986716" onclick="nclk(event, 'home.editnfimg', '', '')">'尹 판박이' 장동혁 메시지…'원팀' 커녕 리더십 흠집[여의뷰]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049909" onclick="nclk(event, 'home.editnfimg', '', '')">60억짜리 압구정 아파트를 39억으로···강남4구·마용성 증여 전수 검증</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049907" onclick="nclk(event, 'home.editnfimg', '', '')">조희대, 이 대통령 초청 오찬서 “사법제도개편 신중하게 해야”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049910" onclick="nclk(event, 'home.editnfimg', '', '')">조국, 윤석열에 “술 덜 깼나···내란범다운 주장”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133107" onclick="nclk(event, 'home.editnfimg', '', '')">올해 드라마는 '진짜 다양성', 예능은 '일반인 성장 스토리' 먹혔다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133111" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 정부 출범 6개월 긍정평가 63%</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133110" onclick="nclk(event, 'home.editnfimg', '', '')">미 금리 인하 앞두고 '가계부담', '물가압박' 언론 엇갈린 시선</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013641237" onclick="nclk(event, 'home.editnfimg', '', '')">"실제 물량 오히려 증가"…쿠팡 배송기사 SNS 고백</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013641338" onclick="nclk(event, 'home.editnfimg', '', '')">與의원들, 김남국 옹호…"돌 같이 맞겠다", "누나는 언어 풍토"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013641108" onclick="nclk(event, 'home.editnfimg', '', '')">금리 결정 앞두고 관망세…비트코인, 1억3800만원대 횡보</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000808886" onclick="nclk(event, 'home.editnfimg', '', '')">자식버린 부모, 유족연금 못 받는다…내년 1월1일 시행</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000808903" onclick="nclk(event, 'home.editnfimg', '', '')">탈북 40대 사망했는데…함께 탈북한 친누나 살인 혐의 조사</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000808921" onclick="nclk(event, 'home.editnfimg', '', '')">가장 매력적인 여행지 1위는 어디?…서울은 10위</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066557" onclick="nclk(event, 'home.editnfimg', '', '')">박지원 "주사 못 맞아 살찐 김건희, 더 삭아야 정신 차려.. 죽어서 감옥 나와야"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066558" onclick="nclk(event, 'home.editnfimg', '', '')">천하람 "내란재판부, 尹 측은 제발 해달라고 물 떠놓고 빌 것.. 그게 죽기 전 풀려날 마지막 방법"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066561" onclick="nclk(event, 'home.editnfimg', '', '')">[제주날씨] 강풍에 체감온도 ‘뚝’, 내일 낮부터 추위  풀려</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035583" onclick="nclk(event, 'home.editnfimg', '', '')">중고생 액상형 전자담배 흡연 비율 증가…아침 거르는 비중도 늘어</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035579" onclick="nclk(event, 'home.editnfimg', '', '')">당신의 논문을 'AI 동료'가 30분만에 평가?…현실화 임박</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035580" onclick="nclk(event, 'home.editnfimg', '', '')">"미세플라스틱, 류마티스 관절염 악화시킨다"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158259" onclick="nclk(event, 'home.editnfimg', '', '')">정청래 "내란 비호 정당에 남은 것은 정당 해산뿐"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158256" onclick="nclk(event, 'home.editnfimg', '', '')">홍준표 "아직 대한민국은 좌파보다 우파가 다수…사이비 걷어내야"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158250" onclick="nclk(event, 'home.editnfimg', '', '')">태안 천리포서 어선 전복…실종자 3명 중 1명 숨진 채 발견</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099242" onclick="nclk(event, 'home.editnfimg', '', '')">‘이재용·구광모의 남자들’ 전면 퇴장…‘2026 재계 리셋’의 의미</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099243" onclick="nclk(event, 'home.editnfimg', '', '')">“글로벌 증시 훈풍” 억만장자 증가세 역대급</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099239" onclick="nclk(event, 'home.editnfimg', '', '')">“나 안아…” Z세대가 캐릭터에 지갑 여는 이유</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004093077" onclick="nclk(event, 'home.editnfimg', '', '')">마크롱 "미국이 우크라 배신할 수도"…유럽 정상들에 불만 토로</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004092974" onclick="nclk(event, 'home.editnfimg', '', '')">'명령 거부' 할 수 있는 공직자 얼마나…비상계엄이 드러낸 딜레마</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004093082" onclick="nclk(event, 'home.editnfimg', '', '')">서울 '첫눈'에 112신고만 약 2천 건…빙판길 4중 추돌사고도</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039192" onclick="nclk(event, 'home.editnfimg', '', '')">7세·9세 자매 성추행한 60대 학원기사.. 항소심서도 징역 6년</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039191" onclick="nclk(event, 'home.editnfimg', '', '')">'선생 나와'.. 둔기 들고 학교 찾아간 학부모 '입건'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039181" onclick="nclk(event, 'home.editnfimg', '', '')">민생회복 소비쿠폰 '국민 10명 중 8명' 만족</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006291" onclick="nclk(event, 'home.editnfimg', '', '')">혈세로 운영하는데 정작 국민이 모르는 '대통령 안가'와 권력자들</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006294" onclick="nclk(event, 'home.editnfimg', '', '')">월급 한푼도 안 써도 5.45년… 서울 전셋집 '못 오를 나무'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006295" onclick="nclk(event, 'home.editnfimg', '', '')">中 광저우차는 왜 '전고체 배터리'를 찜했나 [경제용어사전]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004563903" onclick="nclk(event, 'home.editnfimg', '', '')">알테오젠, 독일서 '키트루다SC' 판매금지 가처분에 10% 급락[이런국장 저런주식]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004563791" onclick="nclk(event, 'home.editnfimg', '', '')">"유튜버들도 여행 포기하더라"…세계에서 가장 더러운 나라 1위 '이곳', 한국은?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004563558" onclick="nclk(event, 'home.editnfimg', '', '')">"이제 마음 놓고 '낮술' 마시자"…52년 만에 오후 주류판매 금지 해제한 '이 나라'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233502" onclick="nclk(event, 'home.editnfimg', '', '')">"서울이 이 정도였어"…런던은 '추락'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233508" onclick="nclk(event, 'home.editnfimg', '', '')">고개 숙인 한예종…'학폭 4호 처분' 합격생 입학 불허</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233474" onclick="nclk(event, 'home.editnfimg', '', '')">"한 푼도 못 준다"…자식버린 부모, 얌체 수급 '제동'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083683" onclick="nclk(event, 'home.editnfimg', '', '')">고혈압 아니라도…OOO 치매 발생위험 ‘쑥’</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083694" onclick="nclk(event, 'home.editnfimg', '', '')">‘사양벌꿀→설탕꿀’로 바뀌나…“고시개정안 12월 중 행정예고”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083673" onclick="nclk(event, 'home.editnfimg', '', '')">‘쿠팡사태’에 농산물 산지 발주량 ‘촉각’</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087827" onclick="nclk(event, 'home.editnfimg', '', '')">“한국 노렸다” 벌써 4만5000명 감염…확산 속도, 이미 통제 밖?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087833" onclick="nclk(event, 'home.editnfimg', '', '')">이부진 아들, 수능 한 개 틀렸다?…의대 아닌 서울대 OOO 간다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087829" onclick="nclk(event, 'home.editnfimg', '', '')">“영하 9도 매서운 추위에 어디로 가라고?…서민들 대출 막혀 집 못산대요”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328615" onclick="nclk(event, 'home.editnfimg', '', '')">‘원조 친윤’ 윤한홍, 장동혁 면전서 “계엄 사과·尹 절연” 언급</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328618" onclick="nclk(event, 'home.editnfimg', '', '')">이준석 “李 정부 인사 메커니즘은 ‘김대중’…김현지·대장동·중앙대”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328616" onclick="nclk(event, 'home.editnfimg', '', '')">尹 재판 증인 나온 문상호 “실탄 인당 10발씩 준비 맞다” [현장영상]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985246" onclick="nclk(event, 'home.editnfimg', '', '')">김성열 "김남국 사직은 꼬리 자르기…진짜 실세는 김현지"[일타뉴스]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985231" onclick="nclk(event, 'home.editnfimg', '', '')">함께 탈북했던 동생 숨지게 한 누나, 얼마 뒤엔 남편도 유서 남기고 숨져</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985267" onclick="nclk(event, 'home.editnfimg', '', '')">김현지 "난 유탄 맞은 것…인사 영향력 없다"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081210" onclick="nclk(event, 'home.editnfimg', '', '')">Media commission investigates Coupang for difficult account deleting process</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081209" onclick="nclk(event, 'home.editnfimg', '', '')">Tongue-shaped, tar-tinged: Ice cream dye sparks concerns among parents</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081212" onclick="nclk(event, 'home.editnfimg', '', '')">'Korea's turn to visit Japan': Lee, Takaichi aim to hold bilateral summit in Nara early next year</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128230" onclick="nclk(event, 'home.editnfimg', '', '')">대한항공·아시아나·진에어 등, ‘기내 와이파이’ 제공… ‘스타링크’ 국내 첫 도입</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128266" onclick="nclk(event, 'home.editnfimg', '', '')">취임 6개월 맞은 李대통령 지지율 62%…민주 43%, 국힘 24%[한국갤럽]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128231" onclick="nclk(event, 'home.editnfimg', '', '')">삼성중공업, 美 조선사와 연쇄 협력… 군수지원함·LNG 벙커링선 사업으로 확대</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155184" onclick="nclk(event, 'home.editnfimg', '', '')">장동혁 "이재명 정권 6개월은 약탈·파괴…민생·법치·안보 모두 무너져"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155183" onclick="nclk(event, 'home.editnfimg', '', '')">서류 위조 '부정 휴가' 즐긴 병사 징역형</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155014" onclick="nclk(event, 'home.editnfimg', '', '')">7·9세 자매에게 성범죄 저지른 60대 학원 운전기사 징역 6년</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497366" onclick="nclk(event, 'home.editnfimg', '', '')">[시니어그룹] "1년 걷기로 소고기 선물" 모르면 손해인 서울시 사업, 그런데요...</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497375" onclick="nclk(event, 'home.editnfimg', '', '')">한국인 첫 인민일보 칼럼 화제... "일본은 군국주의 망상 버려야"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497377" onclick="nclk(event, 'home.editnfimg', '', '')">경기도교육감 여론조사, 안민석 17% 임태희 16% 유은혜 13.9%</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001356983" onclick="nclk(event, 'home.editnfimg', '', '')">’광복로 트리축제’ 오늘 개막…빛과 어우러진 K콘텐츠 테마</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001356982" onclick="nclk(event, 'home.editnfimg', '', '')">'김건희에 로저비비에 클러치백 선물' 김기현 부인 특검 출석</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001356878" onclick="nclk(event, 'home.editnfimg', '', '')">[영상] ‘원통 아동학대’ 유치원 대표가 부산시 3급 보좌관… 책임론 확산</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601361" onclick="nclk(event, 'home.editnfimg', '', '')">“누가 尹에 몰래 술 줬나?”…‘계엄 1년’ 윤석열 옥중메시지에 유인태 일침</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601362" onclick="nclk(event, 'home.editnfimg', '', '')">“5만원권이 도로에 가득”…서울 한복판서 돈다발 뿌려진 사연</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601412" onclick="nclk(event, 'home.editnfimg', '', '')">지금은 맞고, 그때는 틀리다? 언젠가는 제자리 찾아갈 환율 [매경데스크]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037350" onclick="nclk(event, 'home.editnfimg', '', '')">[오늘의 급등주] 고터 재개발로 ‘9연상’한 천일고속, 주춤하다 다시 상승세</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037348" onclick="nclk(event, 'home.editnfimg', '', '')">전병우·신상열… 연말 재계 3세 고속 승진 바람</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037345" onclick="nclk(event, 'home.editnfimg', '', '')">삼성전자, 두 번 접는 갤럭시Z 트라이폴드 공개</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277448" onclick="nclk(event, 'home.editnfimg', '', '')">Social media abuzz over Samsung scion's near-perfect Suneung score</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277447" onclick="nclk(event, 'home.editnfimg', '', '')">Supreme Court confirms 5-year sentence for driver responsible for 9 deaths</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277450" onclick="nclk(event, 'home.editnfimg', '', '')">How Koreans once celebrated snow</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045741" onclick="nclk(event, 'home.editnfimg', '', '')">대구시 국비 '9조 원' 넘었지만···TK 신공항 예산은 '0'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045740" onclick="nclk(event, 'home.editnfimg', '', '')">경북 국비 '12조 원' 시대···SOC 줄고 다른 분야 증액</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045738" onclick="nclk(event, 'home.editnfimg', '', '')">① 미등록 외국인 강제 단속···농어촌에 도심까지 인력난</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089127" onclick="nclk(event, 'home.editnfimg', '', '')">“내년엔 코스피 6000 간다”...맥쿼리가 꼽은 핵심 섹터는?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089090" onclick="nclk(event, 'home.editnfimg', '', '')">BTS 슈가 모친, 173억 한남동 건물주…1층 친형 식당</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089151" onclick="nclk(event, 'home.editnfimg', '', '')">억만장자 13% 자산 증가에도 한국 부자 수 급감, 왜?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028667" onclick="nclk(event, 'home.editnfimg', '', '')">충북대·교통대 투표 '엇갈린 결과'...통합 적신호</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028662" onclick="nclk(event, 'home.editnfimg', '', '')">조국, 윤석열 '계엄 1년' 입장문에 "술이 덜 깬 것인가, 리플리 증후군인가"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028668" onclick="nclk(event, 'home.editnfimg', '', '')">[자막뉴스] 전 연인 살해 유기한 남성, 54살 김영우 신상공개</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002754973" onclick="nclk(event, 'home.editnfimg', '', '')">“여성 발만 보면 흥분” 찜질방서 잠든 여성들 53회 추행한 남성</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755043" onclick="nclk(event, 'home.editnfimg', '', '')">이준석 “이재명 정부는 ‘김·대·중’ 정부” 무슨 뜻?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755025" onclick="nclk(event, 'home.editnfimg', '', '')">[속보]홍준표 “아직 대한민국은 좌파보다 우파가 다수…사이비 걷어내야”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901425" onclick="nclk(event, 'home.editnfimg', '', '')">추미애, '서울 폭설' 오세훈 저격… "한강버스 때문에 눈 안 치웠나"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901396" onclick="nclk(event, 'home.editnfimg', '', '')">민주당 표 '정년연장안'…1972년생 '김낙수 부장'은 몇 년 더 일하게 될까</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901428" onclick="nclk(event, 'home.editnfimg', '', '')">산양·황새·사육곰… "2025년 올해의 동물 뉴스, 시민이 뽑아주세요"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037569" onclick="nclk(event, 'home.editnfimg', '', '')">“밖에서는 시민들이, 안에서는 국회 직원들이 목숨을 걸었다” [당신의 6시간 ⑩]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037568" onclick="nclk(event, 'home.editnfimg', '', '')">국립중앙박물관에 왜 CT 장비가 설치됐을까</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037566" onclick="nclk(event, 'home.editnfimg', '', '')">주인 없는 개는 어디서 살까? [사람IN]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089780" onclick="nclk(event, 'home.editnfimg', '', '')">'씨○' 욕설로 '메뉴 홍보'…이탈리아 식당 논란</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089781" onclick="nclk(event, 'home.editnfimg', '', '')">강득구 "세상이 김남국에 돌 던진다면 함께 맞겠다"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089788" onclick="nclk(event, 'home.editnfimg', '', '')">경기도의회 갈등 봉합되나…조혜진 道 비서실장 사퇴</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080187" onclick="nclk(event, 'home.editnfimg', '', '')">내란전담재판부 어떤 입장이세요?…조희대 “법원장 의견 듣겠다” [지금뉴스]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080101" onclick="nclk(event, 'home.editnfimg', '', '')">충남 태안 해상서 어선 전복…3명 사망·1명 실종</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080030" onclick="nclk(event, 'home.editnfimg', '', '')">[영상] 반환된 판다 ‘샹샹’ 우리 앞…일본인 ‘성지순례’ 북적</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052752" onclick="nclk(event, 'home.editnfimg', '', '')">기약 없는 신냉전, 중립 재조명이 필요한 게 아니다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052753" onclick="nclk(event, 'home.editnfimg', '', '')">성폭력 피해 엘리트 선수, 그는 칼로 무엇을 베려 했나</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052755" onclick="nclk(event, 'home.editnfimg', '', '')">베트남전 파병 군인의 고통까지 살피는 법안</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101810" onclick="nclk(event, 'home.editnfimg', '', '')">미래·키움 자사주 소각하는데…30년째 요지부동, 어디?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101803" onclick="nclk(event, 'home.editnfimg', '', '')">커플 대세는 이제 ‘한남일녀’?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101807" onclick="nclk(event, 'home.editnfimg', '', '')">‘미스터 폴더블’서 ‘미스터 AI’로 변신 중…노태문 삼성전자 사장 [CEO 라운지]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076027" onclick="nclk(event, 'home.editnfimg', '', '')">[약가인하 폭풍전야]⑥ 삼진제약, 매출 60% 국내 제네릭…수익성 악화 불가피</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076043" onclick="nclk(event, 'home.editnfimg', '', '')">[통합 현대중공업 출범]②HD현대마린엔진, 미포 발 캡티브로 존재감 강화</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076041" onclick="nclk(event, 'home.editnfimg', '', '')">넷마블, 단기차입·상환 반복… 재무활동이 현금흐름 좌우</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598380" onclick="nclk(event, 'home.editnfimg', '', '')">불수능 뚫고 일반고서 2년째 ‘만점’…주인공은 누구</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598390" onclick="nclk(event, 'home.editnfimg', '', '')">“걷는 게 기적이었는데…” 허리도 못 펴던 이봉주, ‘경이로운 근황’</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598335" onclick="nclk(event, 'home.editnfimg', '', '')">“성폭행당해 낳은 아들이 결혼식에 아빠 초대한다네요” 女 충격 사연</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008073" onclick="nclk(event, 'home.editnfimg', '', '')">“올해부터 우리 마을은 남녀차별 없이 임금 지급한다”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008072" onclick="nclk(event, 'home.editnfimg', '', '')">‘무지개 노인’도 잘 살 수 있는 나라를 위한 노력</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008071" onclick="nclk(event, 'home.editnfimg', '', '')">지하철 장애인 시위 현장의 ‘둘리아’들</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038533" onclick="nclk(event, 'home.editnfimg', '', '')">"언론중재법 개정안 폐기해야"… 신문협, 문체부에 의견서</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038532" onclick="nclk(event, 'home.editnfimg', '', '')">김종철 방미통위원장 후보자 "여야, 7인 위원회 구성 힘써달라"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038531" onclick="nclk(event, 'home.editnfimg', '', '')">'무단협 2년째' KBS본부노조, 쟁의투표 82% 찬성 가결</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095335" onclick="nclk(event, 'home.editnfimg', '', '')">“엄마, 나 다 나았어”… ‘사형선고’ 소아암의 기적</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095331" onclick="nclk(event, 'home.editnfimg', '', '')">과일도 살 찐다고? 당분 적어 다이어트에 좋은 과일 5가지</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095322" onclick="nclk(event, 'home.editnfimg', '', '')">보리밥, 귀리밥, 나물밥 번갈아 먹었더니…혈당 스파이크, 체중에 변화가?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101361" onclick="nclk(event, 'home.editnfimg', '', '')">“약보다 더 효과적” 기침 빨리 멈추려면 물에 ‘이것’ 넣어라… 뭘까?</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101360" onclick="nclk(event, 'home.editnfimg', '', '')">한 입에 몸 뜨끈해지는 ‘당뇨식 마녀수프’[밀당365]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101359" onclick="nclk(event, 'home.editnfimg', '', '')">아내에게 ‘이 말’ 자주 하면, 관계 만족도 올리는 데 큰 도움</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008644851" onclick="nclk(event, 'home.editnfimg', '', '')">[단독]재정경제부에 '민생경제국' 신설…물가·복지·고용 한곳서 총괄</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008644926" onclick="nclk(event, 'home.editnfimg', '', '')">'특검 첫 출석' 김기현 아내, '김 여사에 전대 지원 요청' 질문에 '침묵'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008645068" onclick="nclk(event, 'home.editnfimg', '', '')">광남고서 또 수능 만점…왕정건 군 "전쟁 현장 보며 의사 꿈 꿔"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313621" onclick="nclk(event, 'home.editnfimg', '', '')">김현지 "난 유탄 맞은 것…누나 동생하는 사이도 아냐" [자막뉴스]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313650" onclick="nclk(event, 'home.editnfimg', '', '')">한예종, '학교폭력 전력' 합격생 입학 불허 결정</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313581" onclick="nclk(event, 'home.editnfimg', '', '')">"패딩 거위털 맞아요?" 전수조사…노스페이스 결국</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689309" onclick="nclk(event, 'home.editnfimg', '', '')">'초유의 사태'인데 접속자는 폭주?…'탈쿠팡' 대신 '앱이용' 최고치</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689520" onclick="nclk(event, 'home.editnfimg', '', '')">"스페인산 믿고 먹었는데"…'치사율 100%' 30년 만의 발생에 화들짝</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689514" onclick="nclk(event, 'home.editnfimg', '', '')">정청래 "내란·외환죄 확실히 처단…고름은 짜내야"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003057" onclick="nclk(event, 'home.editnfimg', '', '')">“아들 편입 서류 보내달라”…  김병기 배우자, '보좌진 사적 동원' 녹취 입수</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003056" onclick="nclk(event, 'home.editnfimg', '', '')">“뉴스타파는 멈추지 않았다”...GIJC 총회서 ‘잠입취재·압수수색’ 공유</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003055" onclick="nclk(event, 'home.editnfimg', '', '')">[다큐 뉴스타파] 내란 1년, 파괴자들</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054050" onclick="nclk(event, 'home.editnfimg', '', '')">한동훈 "김현지 버리지 않으면 정권 끝까지 못간다...특별감찰관 임명해야"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054044" onclick="nclk(event, 'home.editnfimg', '', '')">추미애 "오세훈, 눈 안치우면 한강버스 인기 올라간다 생각하나"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054042" onclick="nclk(event, 'home.editnfimg', '', '')">최태원 장녀 최윤정, 전략본부장 선임...'차기 경영진' 시계 빨라지나</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018966" onclick="nclk(event, 'home.editnfimg', '', '')">“한국의 지정학적 불안이 감정적 충돌의 두 기둥 키웠다”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018964" onclick="nclk(event, 'home.editnfimg', '', '')">“플라스틱 식민주의 멈춰주세요” 12세 소녀, 국제 환경 의제 흔들다</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018963" onclick="nclk(event, 'home.editnfimg', '', '')">“집값 낮추겠다는 정부 공언 믿어선 안 돼…서울 집 사라”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923117" onclick="nclk(event, 'home.editnfimg', '', '')">김건희에 260만 원 로저비비에 왜 줬냐는 질문에 침묵…김기현 부인 특검 출석</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923085" onclick="nclk(event, 'home.editnfimg', '', '')">조세호, 조폭 연루설 강력 부인…"법적 대응 검토 중"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923097" onclick="nclk(event, 'home.editnfimg', '', '')">"거위털 아니었어?"… 노스페이스 '충전재 오기재' 13종 전량 환불</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002779935" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 한강버스 좌초 때 탑승객 26명 적게 신고…경찰도 혼선</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002779974" onclick="nclk(event, 'home.editnfimg', '', '')">조갑제 “윤석열 입장문, 학교서 가르쳐야…못 쓴 글 표본으로”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002779973" onclick="nclk(event, 'home.editnfimg', '', '')">김건희에 ‘로저 비비에 선물’한 김기현 부인 특검 출석</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575144" onclick="nclk(event, 'home.editnfimg', '', '')">'취임 6개월' 李 대통령 지지율 62%…민주 43%·국힘 24%</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575071" onclick="nclk(event, 'home.editnfimg', '', '')">중국인 해킹 당한 쿠팡, 또 '중국인 모집'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575056" onclick="nclk(event, 'home.editnfimg', '', '')">박나래 측, '매니저 갑질' 의혹에 "법무법인과 입장 정리 중"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159390" onclick="nclk(event, 'home.editnfimg', '', '')">“고등학생 제자와 부적절 관계 여교사는 내 前 며느리” 전 야구 국가대표팀 류중일 감독 국민청원 호소</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159428" onclick="nclk(event, 'home.editnfimg', '', '')">창원 모텔 흉기난동 20대, 호감 느낀 여중생에 남친이 있다는 말 듣고 범행 추정</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159549" onclick="nclk(event, 'home.editnfimg', '', '')">눈 내린 강원…퇴근길 교통대란 이어져</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013131" onclick="nclk(event, 'home.editnfimg', '', '')">오리엔티어링의 '시작과 끝' 지도 [OMM JAPAN 즐기기]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013130" onclick="nclk(event, 'home.editnfimg', '', '')">짐은 가볍게 필수품만, 10kg 미만으로 [OMM JAPAN 장비]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013129" onclick="nclk(event, 'home.editnfimg', '', '')">임금이 타는 명마가 태어난 곳 [한라산 어승생악]</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377555" onclick="nclk(event, 'home.editnfimg', '', '')">갈 곳 잃은 1조2240억원... 日 “상속인 없다” 작년 국고 귀속 유산 최대</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377470" onclick="nclk(event, 'home.editnfimg', '', '')">“한국 오빠와 데이트 할래?”… 브라질서 한류 팬 노린 성착취 사이트 수사</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377623" onclick="nclk(event, 'home.editnfimg', '', '')">'야간 모드 인물 사진' 사라진 아이폰17 프로, 다운그레이드?… 애플은 모르쇠</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131749" onclick="nclk(event, 'home.editnfimg', '', '')">“죽은 언니들 몫까지 싸우겠다”… 다시 소송에 나선 미군 ‘위안부’ 3인의 증언</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131922" onclick="nclk(event, 'home.editnfimg', '', '')">청년 여성, 수도권으로 ‘생존 이동’…소득 25.5% 올라</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131848" onclick="nclk(event, 'home.editnfimg', '', '')">한국 ‘페미 소설’ 넷플릭스 영화로...나가노 메이 주연</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373273" onclick="nclk(event, 'home.editnfimg', '', '')">美 FBI, '5년 장기 미제' 1·6 의회폭동 폭탄 설치 용의자 전격 체포</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373278" onclick="nclk(event, 'home.editnfimg', '', '')">'현지누나' 논란…김현지 "유탄 맞았다…인사권? 그거 아냐"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373258" onclick="nclk(event, 'home.editnfimg', '', '')">엔 캐리 청산 재현 공포?...日 금리 인상 신호에 채권시장 요동</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211631" onclick="nclk(event, 'home.editnfimg', '', '')">일반인도 개발 가능…커지는 AI 코딩 시장, 구글도 가세</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211643" onclick="nclk(event, 'home.editnfimg', '', '')">손정의, 10개월 만에 방한…이재명 대통령과 AI 전략 논의에 '쏠린 눈'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211659" onclick="nclk(event, 'home.editnfimg', '', '')">"절차상 하자 없어"…유진, YTN 최대주주 변경 승인 취소에 ‘항소’</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417483" onclick="nclk(event, 'home.editnfimg', '', '')">보수 장성철 "'끝났다 장동혁, 살았다 김종혁'…국힘은 2월에 새 지도체제 꾸릴 것"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417468" onclick="nclk(event, 'home.editnfimg', '', '')">與 서영교, '성추행 의혹' 장경태 감싸다 2차 가해 논란</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417463" onclick="nclk(event, 'home.editnfimg', '', '')">"감옥에서 尹한테 술 주나?" …계엄 1년 윤석열 황당 메시지에 유인태 일침</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818675" onclick="nclk(event, 'home.editnfimg', '', '')">아모레퍼시픽 5년 만에 희망퇴직…근속 15년 이상 등 대상</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818655" onclick="nclk(event, 'home.editnfimg', '', '')">추미애 “여의도서 하남까지 5시간 걸려” 오세훈 저격</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818676" onclick="nclk(event, 'home.editnfimg', '', '')">‘윤핵관’의 작심비판 “尹 절연 없이는 똥 묻은 개”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000478877" onclick="nclk(event, 'home.editnfimg', '', '')">"엔비디아, 현금이 많아서 문제"…올해만 26조 투자 약속</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000478822" onclick="nclk(event, 'home.editnfimg', '', '')">보름 만에 10배 뛰었다…1억 넣었으면 10억 된 '이 주식'</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000478901" onclick="nclk(event, 'home.editnfimg', '', '')">서울 출근길 지하철 20회 증차…버스 집중배차 30분 연장</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487707" onclick="nclk(event, 'home.editnfimg', '', '')">김남국 사퇴날 새벽 문자 한통…강득구 "돌 함께 맞겠다" 왜</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487516" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] "호주 출장 내내 밤마다 술판"…'음주폭언' 전주시장 또 논란</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487467" onclick="nclk(event, 'home.editnfimg', '', '')">믿었던 유명 패딩의 배신…"거위털 아냐" 들통난 13개 제품 뭐길래</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413358" onclick="nclk(event, 'home.editnfimg', '', '')">‘김건희에 로저비비에 청탁’ 김기현 부인, 묵묵부답으로 특검 출석</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413351" onclick="nclk(event, 'home.editnfimg', '', '')">한예종, ‘학교폭력 전력’ 합격생 입학 최종 불허</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413331" onclick="nclk(event, 'home.editnfimg', '', '')">[속보]조희대 “법원장 의견 들어볼 것”···오늘 전국법원장회의, 내란재판부 등 논의</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117469" onclick="nclk(event, 'home.editnfimg', '', '')">강득구 "김남국과 돌 함께 맞겠다…또 공직 떠나는 마음 얼마나 힘들까"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117468" onclick="nclk(event, 'home.editnfimg', '', '')">정청래 "尹, 뻔뻔한 자기 합리화 궤변…장동혁은 재창·삼창 반복"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117467" onclick="nclk(event, 'home.editnfimg', '', '')">국방부, '보고 없이 대북전단 살포 의혹' 국군심리전단 조사</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002282891" onclick="nclk(event, 'home.editnfimg', '', '')">민주, 연내 사법개혁 완료...국민의힘 "안하무인"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002282774" onclick="nclk(event, 'home.editnfimg', '', '')">내란재판부·법왜곡죄 강행...오늘 전국 법원장 대책 논의</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002282866" onclick="nclk(event, 'home.editnfimg', '', '')">외국인 매도로 코스피 4,020선 후퇴...오늘 상승할까</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098419" onclick="nclk(event, 'home.editnfimg', '', '')">강득구 "세상이 던지는 돌 함께 맞겠다...여전히 김남국 사랑"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098416" onclick="nclk(event, 'home.editnfimg', '', '')">'학폭 처리 불만' 학부모, 둔기 들고 학교 쫓아가 욕설</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098381" onclick="nclk(event, 'home.editnfimg', '', '')">장성 육군 훈련장서 '펑'…폭발사고로 부사관 4명 부상</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178125" onclick="nclk(event, 'home.editnfimg', '', '')">"감히 대통령 면전서"…정청래, 대법원장 향해 "조희대, 용서 못받아"</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178309" onclick="nclk(event, 'home.editnfimg', '', '')">野윤한홍, 장동혁 면전서 “국정마비가 계엄원인? 尹 벗어던져야”</a>,
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178161" onclick="nclk(event, 'home.editnfimg', '', '')">“버스에서 5만원권 뿌렸다”…을지로에서 무슨 일이</a>]

# %%
from urllib.request import urlopen
import bs4
import pandas as pd

# %%
url = 'https://news.naver.com'
html = urlopen(url)
bs_obj = bs4.BeautifulSoup(html, 'html.parser')

# %%
# 네이버 뉴스 섹션메뉴 태그 확인(개발자도구)
# body > section > header > div.Nlnb._float_lnb > div > div > div.Nlnb_left._lnb_scroll > div > div > ul
# selector가 너무 길어서 유용하지 않아 보임
# 직접 확인한 태그와 클래스 속성 사용
# ul 태그의 class : Nlnb_menu_list
uls = bs_obj.findAll("ul",{"class":"Nlnb_menu_list"})
len(uls) # 원소가 1개이므로
ul = bs_obj.find("ul",{"class":"Nlnb_menu_list"})
ul
# Out:
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem"><span class="Nitem_link_menu">알고리즘 안내</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/ombudsman/errorArticleList" onclick="nclk(event,'lnb.correct','','');" role="menuitem"><span class="Nitem_link_menu">정정보도 모음</span></a></li>
# </ul>

# %%
lis = ul.findAll('li')
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text," : ",a_tag['href'])
# Out:
# 언론사별  :  https://news.naver.com/?viewType=pc
# 정치  :  https://news.naver.com/section/100
# 경제  :  https://news.naver.com/section/101
# 사회  :  https://news.naver.com/section/102
# 생활/문화  :  https://news.naver.com/section/103
# IT/과학  :  https://news.naver.com/section/105
# 세계  :  https://news.naver.com/section/104
# 랭킹  :  https://news.naver.com/main/ranking/popularDay.naver
# 신문보기  :  https://news.naver.com/newspaper/home?viewType=pc
# 오피니언  :  https://news.naver.com/opinion/home
# TV  :  https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크  :  https://news.naver.com/factcheck/main
# 알고리즘 안내  :  https://media.naver.com/algorithm
# 정정보도 모음  :  https://news.naver.com/ombudsman/errorArticleList

# %%
# li태그를 이용해서 추출
lis = bs_obj.findAll("li",{"class" : "Nlist_item"})
len(lis)
# Out:
# 14

# %%
for li in lis :
    a_tag = li.find('a')
    print(a_tag.text)
    print(a_tag['href'])
# Out:
# 언론사별
# https://news.naver.com/?viewType=pc
# 정치
# https://news.naver.com/section/100
# 경제
# https://news.naver.com/section/101
# 사회
# https://news.naver.com/section/102
# 생활/문화
# https://news.naver.com/section/103
# IT/과학
# https://news.naver.com/section/105
# 세계
# https://news.naver.com/section/104
# 랭킹
# https://news.naver.com/main/ranking/popularDay.naver
# 신문보기
# https://news.naver.com/newspaper/home?viewType=pc
# 오피니언
# https://news.naver.com/opinion/home
# TV
# https://news.naver.com/main/tv/index.naver?mid=tvh
# 팩트체크
# https://news.naver.com/factcheck/main
# 알고리즘 안내
# https://media.naver.com/algorithm
# 정정보도 모음
# https://news.naver.com/ombudsman/errorArticleList

# %%
# 수집 데이터 df로 구성 후 저장
section = []
link = []

# %%
for li in lis :
    a_tag = li.find('a')
    section.append(a_tag.text)
    link.append(a_tag['href'])

# %%
col_dict = {'section':section, "link":link}
news_section_df = pd.DataFrame(col_dict)

# %%
news_section_df
# Out:
#     section                                               link
# 0      언론사별                https://news.naver.com/?viewType=pc
# 1        정치                 https://news.naver.com/section/100
# 2        경제                 https://news.naver.com/section/101
# 3        사회                 https://news.naver.com/section/102
# 4     생활/문화                 https://news.naver.com/section/103
# 5     IT/과학                 https://news.naver.com/section/105
# 6        세계                 https://news.naver.com/section/104
# 7        랭킹  https://news.naver.com/main/ranking/popularDay...
# 8      신문보기  https://news.naver.com/newspaper/home?viewType=pc
# 9      오피니언                https://news.naver.com/opinion/home
# 10       TV  https://news.naver.com/main/tv/index.naver?mid...
# 11     팩트체크              https://news.naver.com/factcheck/main
# 12  알고리즘 안내                  https://media.naver.com/algorithm
# 13  정정보도 모음  https://news.naver.com/ombudsman/errorArticleList

# %%
# news_section_df.to_csv('./navew_news_section.csv', encoding='euc-kr')
news_section_df.to_csv('./Myexam/naver_news_section.csv', encoding='utf-8')
