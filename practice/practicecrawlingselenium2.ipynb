# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
article_list = []
def get_article(page):
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    driver.get("https://news.naver.com/section/10" + str(page))
    articles = driver.find_elements(By.CSS_SELECTOR,'#newsct li')
    for article in articles:
        try:
            tmp_elements = article.find_elements(By.CSS_SELECTOR, '.sa_text strong')
            if tmp_elements:
                title = tmp_elements[0].text
            else:
                tmp_elements2 = article.find_elements(By.CSS_SELECTOR, '.ss_text a')
                if tmp_elements2:
                    title = tmp_elements2[0].text
                else:
                    title = "해당 정보 없음"
            article_list.append(title)
        except:
            print("에러 발생!")
    print("end :", page)
    driver.quit()

# %%
# %%time
for page in range(1, 5):
    get_article(page)
# Out:
# end : 1
# end : 2
# end : 3
# end : 4
# CPU times: user 216 ms, sys: 141 ms, total: 357 ms
# Wall time: 10.4 s

# %%
article_list
# Out:
# ['신한라이프 신임사장 후보에 천상영 신한지주 부사장',
#  '3분기 은행권 보통주자본비율 소폭 하락…“환율 영향 불확실성, 추가 모니터링”',
#  'HD현대 “2030년 매출 100조 달성 목표”',
#  '한미약품 ‘한국인 맞춤형 비만약’, 식약처 신속심사 지정',
#  '구윤철 “고환율 해결책은 국가·기업 경쟁력 제고”',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '리브스메드 "글로벌 수술 로봇 시장 리더십 장악할 것"',
#  '\'일라이릴리 픽\' 알지노믹스 "유전자치료제 선도기업 될 것"',
#  '\'초소형 위성\' 나라스페이스 "뉴 스페이스 시대 선도"',
#  '\'미세바늘업체\' 쿼드메디슨 "약물전달 패러다임 전환 선도"',
#  '해당 정보 없음',
#  '해당 정보 없음',
#  '美 정부 “AI 다음은 로봇” 점찍자…韓 기업도 웃는다',
#  '기아 80주년…정의선 “기아의 미래는 도전”',
#  "기아 창립 80주년⋯'비전 메타투리스모' 최초 공개",
#  '반도체 호조에 뇌수술로봇까지…2주만에 주가 53% 뜬 고영',
#  '키움운용, S&P500 승자만 고르는 ‘한국판 SPMO’ ETF 9일 신규 상장',
#  "개인정보 싹 털린 쿠팡, 이용자 수 18만명 '뚝'…대규모 이탈 본격화 조짐",
#  '올 겨울 최대전력수요, 88.8∼94.5GW 예상…기후부, 첫 전력 수급 대책',
#  "미래·KB·카카오 'AI 혁신금융 서비스' 발 뺐다",
#  'SK·에이치라인해운 본사 부산행…"해양수도권 조성의 화룡점정"(종합)',
#  "철강 불황이라더니...'KRX 철강' 지수 상승률 상위권, 이유는",
#  '"트럼프가 힘 실어주나"…훨훨 날아오른 로봇주',
#  '李 \'AI 기본사회\' 구상…손정의 "다음은 초인공지능"',
#  '이탈 본격화하나…쿠팡 이용자, 나흘 만에 줄었다',
#  'DS증권 "현대차그룹, 日토요타와 닮은꼴 지배구조 리레이팅에 주목"',
#  '구자균 LS일렉트릭 "에너지고속도로 국가 핵심 인프라 될 것"',
#  "SKC 투입된 'SK㈜의 투자 전문가'…새 곳간지기에 박동주 CFO",
#  '산업부-英 Arm, 반도체 설계인력 1400명 양성…“귀중한 자산 될 것”',
#  '"홀린듯이 차도로"…서울 한복판에 5만원권 \'우수수\' 무슨 일이',
#  '[단독] 쿠팡 등록한 카드 정말 괜찮나…금감원, 조사 연장',
#  "LIG넥스원, 임단협 교착…방산 '최고 연봉' 신익현 대표 보수가 발목",
#  '직구 시켜놓고 통관번호 재발급..."배송 지연" 세관 막힌 택배 수두룩',
#  '얼어붙은 지방 부동산…부동산업 대출 첫 ‘3분기째 감소’',
#  '10월 경상수지 반토막…해외 주식은 역대 최대',
#  '내년 6천피 전망까지…코스피 장중 4080선 탈환',
#  '롯데·HD현대 자율협의회 개최…석화 구조조정 대장정 첫발(종합)',
#  '신한운용, SOL 코리아고배당 ETF 순자산 2000억 돌파',
#  "'아파트 속 스타필드'…파주 운정에 1호점",
#  '자오창펑 바이낸스 창업자 “블록체인과 전통 금융 통합될 것” [매일코인]',
#  "[어바웃 C] '손지웅 유임'으로 굳힌 LG화학 바이오 라인…후기임상·상업화 고심",
#  '경동제약, 창사 이래 최대 규모 설비 투자 단행',
#  "[CEO풍향계] '책임회피 논란' 김범석…'하나의 DNA' 함영주",
#  '비상계엄 해제 1년…韓경제, 충격 컸지만 회복 빨랐다',
#  '“여보, 집값 미쳤어" 한숨 푹푹 아내...24평형 50억, 실화냐',
#  '산업부, Arm과 반도체 설계 인재 1400명 양성 나선다',
#  '[단독] 금감원, MBK 임직원에 감봉 포함 중징계… 김병주 회장은 제외',
#  "자전거로 시작해 PBV까지…기아 80년 두 번의 부도 '도전과 분발'",
#  '“내가 낳았으니 유산달라”…자식 버린 부모, 유족 연금 한푼도 못받는다',
#  '간 큰 고3 학생들, 주말 교장실 털었다…교사·학생 개인정보 빼돌려',
#  '‘SKY’ 정시 합격선 인문 395점·자연 392점 예측[세상&]',
#  "선원 옷 벗겨 물고문, 폭행...숨지자 '쇠뭉치' 엮어 바다에 던진 선장",
#  '법원, ‘법정소란’ 김용현 측 권우현 변호사에 ‘감치 5일’ 선고',
#  '',
#  '',
#  '',
#  '',
#  '조희대 사법개혁 입 열었다…“공론화 거쳐 전문가 판단 바탕으로 신중히”',
#  '2.7억 가로챈 전세사기 가담 30대 여성…징역형 집행유예',
#  '‘매니저 갑질 의혹’ 박나래 경찰 수사 받는다…상해 등 혐의',
#  '‘SKY’ 정시 합격선 인문 395점·자연 392점 예측',
#  "부동산 투기 의혹과 '쓰고 버리는' 교원…정부는 세종대를 감사하라",
#  '[단독] 김건희 특검, ‘조사 불응’ 구세현 전 웰바이오텍 대표 강제구인',
#  '‘미미미누’ 영상서 10초만에 수학 푼 학생… 알고 보니 ‘수능 만점자’',
#  '“살아계신가요”…“진짜 큰일날 뻔” 선우은숙 며느리에 생긴 일',
#  '서울 자양5구역 부지에 600면 임시주차장…내년 1월 개장 목표',
#  '경찰 "쿠팡 개인정보 유출 2차피해, 현재까지 확인 안 돼"',
#  '첫눈인데 폭설?집중호우 닮은 ‘기습폭설’ 앞으로 더 자주 온다[날씨가 왜 이래]',
#  '"저 갇혔어요" 신고 출동해보니 원룸 전체가 성매매 현장(종합)',
#  '미끄러지고 12대 추돌 사고…폭설 퇴근 이어 빙판 출근',
#  '짧은 첫눈에도 수도권 \'교통대란\'..."제설 엉망" 분통',
#  "'창원 모텔 흉기' 피의자, 과거 성범죄도 SNS로 10대 유인",
#  '"공부 안 하는 시간엔 매일 독서"...불수능 만점 비결',
#  "국힘 창원시의원들, '김주열 역사탐방' 등 민주화기념 예산 삭감 논란",
#  '尹, 지귀연 향해 폭풍설명 “부정선거 조사는 보통일 아냐” [현장영상]',
#  "'백현동 뇌물' 민주연구원 전 부원장, 항소심서 형량 늘어…징역 3년",
#  '김기현 의원 아내 특검 조사 중…추경호 이번 주 기소 전망',
#  '경찰 "쿠팡 유출 정보 악용된 2차피해 사례 현재까지 미확인"',
#  '유경선, 최대주주 취소 판결 뒤 YTN 노조사무실 찾아…"국면전환 수작 거부"',
#  '아내 살해 17년형 받은 60대, 갑자기 이틀 만에 사망…사인 불명',
#  "돌연 '파산 선언' 미션캠프…전국서 피해 속출, 경찰 곧 수사 돌입",
#  '자고 일어나니 겨울왕국…“주머니에 손넣고 걷다간” 전문의 경고 [헬시타임]',
#  "'갑질 의혹' 양양군 공무원, 구속심사 마쳐…질문엔 '묵묵부답'(종합)",
#  '"방에 갇혔다" 신고에 출동했더니…평범한 원룸이 성매매 거점으로 드러나',
#  "김건희 집사 '엑싯' 도왔나…조영탁 IMS모빌리티 대표 구속기로",
#  '특검, 한동훈 증인신문 신청 철회…추경호 곧 기소',
#  "'8억 뇌물' 전준경 前민주연 부원장 2심 징역 3년…1심보다 늘어",
#  "우리 동네 눈사람 전시회...'천사와 라바' [앵커리포트]",
#  '“사제 간 성관계는 학대” 류중일 감독 며느리 사건에 이수정 교수 일침',
#  "'억대 금품' 전준경 민주연 前부원장 2심서 형량 늘어 징역 3년",
#  '[단독] "인증번호 돌연 쏟아진다"…쿠팡, 개인정보 민원 압도적 1위',
#  '[속보] 조희대 대법원장 “사법제도 개편, 충분한 공론화·전문가 판단 거쳐야”',
#  '임영웅, 폭설에 삽 들고 "제설도 작전이다" [앵커리포트]',
#  '조희대 대법원장 “그릇된 사법개편은 국민에 치명적 피해”',
#  "'4명 부상' 강남 냉면집 돌진 사고 피의자, 처벌 안 받는다…왜?",
#  '경찰 “쿠팡 개인정보 유출, 2차 피해 의심 정황 없어”',
#  '7년전 학폭·성폭행에 중형 구형…피해자 "이젠 나아갈 수 있게"',
#  '내년 국가유산청 예산, 8% 늘어난 1조4971억원…K-헤리티지 확산',
#  '눈 그쳤지만 곳곳 빙판길…주말에 추위 풀려[날씨]',
#  '걷는 사람에게만 허락된 절경‥금오도 비렁길',
#  'APEC 홀릴 경주의 특별한 밤',
#  '지금, 바다를 여행하는 가장 요즘 다운 방법',
#  '푸른 물결로 춤추는 가파도 청보리밭',
#  '지옥 같던 9분... 죽일 듯 싸웠던 상대를 안았다',
#  '"달걀, 우유도 안 먹어" 했더니... 육식인들은 회초리를 들었다',
#  '여름도 아닌데... 왜 짧은 치마 입고 응원해야 하나요?',
#  '채식주의자 남편 등쌀에 밥상 엎는 아내? 실제는 이렇습니다',
#  '[날씨] 퇴근길도 빙판 유의...주말 추위 풀려, 중북부 약한 비',
#  "수능 만점자, '미미미누' 유튜브 출연 모습 화제",
#  '"8분 거리를 8시간 걸렸어요" 경기북부 제설 행정 \'뭇매\'',
#  '두 가지 치매 함께 발병한 ‘혼합형 치매’ 환자는 뇌의 ‘이곳’이 빛났다',
#  '“쌍둥이 중 누굴 살리겠습니까?”…태아 한 명 희생해야 한다는데, 부모의 선택은?',
#  "45만원 임윤찬 공연서 쩌렁쩌렁 통화…최악의 '관크'에 분노",
#  '“늦기전에 중증환자 판별”…‘당뇨병’ 새 분류기준 나왔다',
#  '“자라고기 먹으면 목 짧은 아기” 임신·출산 문화 이렇게 변했네',
#  "'백신 부정' 美 케네디 장관, 면역효과 높이는 알루미늄 보조제에 태클",
#  '[날씨] 도로 미끄럼 주의…낮에도 쌀쌀, 주말 추위 풀려',
#  '“아빠도 아들도 신나겠네”...국내 최대 규모 레고 매장 들어섰다는데',
#  '“노쇠 수컷 쥐 수명 70% 연장”…두 약물 조합, 현대판 ‘불로초’ 될까?',
#  '2년 사경 넘나들다 회복한 희귀 자가면역뇌염(AE) 환자',
#  "'저런 건 어디서 샀을까?' 영상에 홀린 듯 빠져들었다",
#  "[신간] 내년 트럼프는?…'이코노미스트 2026 세계대전망'",
#  "사과, 요구르트 후식 아닌 '간식'으로 먹었더니…혈당, 체중에 어떤 변화가?",
#  '‘항불안제 먹으면 머리 나빠진다’는 말, 사실일까?',
#  "너도나도 '힐링'하는데 왜 불행할까… '행복도 58위' 한국이 놓친 한 가지",
#  '위기의 ‘초보 부모들’…출산 첫 해 ‘이 병’ 위험 크다',
#  '[날씨] 오후 영상권 회복...주말 동장군 물러나',
#  '中 제외 글로벌 전기차 판매 27.8%↑…현대차 3위 지켜',
#  '한파·대설특보 해제…폭설로 빙판, 미끄럼 주의',
#  '[조용준의 여행만리] 걷는 사람에게만 허락된 절경‥금오도 비렁길',
#  '정의선 회장 “기아는 정제 안 된 다이아몬드… 계속 도전할 것”',
#  "'불수능'에 합격 예상점수 올라…서울대 의예 422∼423점, SKY 인문 395점·자연 392점",
#  "[날씨] 빙판 얼었다 녹기 반복 '미끄럼' 주의...주말 추위 풀려",
#  '[날씨] 한낮 쌀쌀, 도로 미끄럼 주의…주말 추위 풀려',
#  '정의선 현대차그룹 회장 "자율주행, 격차보다 중요한 것은 안전"',
#  '[뉴스나우] 첫눈인데 또 폭설...올해 한파·폭설 얼마나?',
#  '[센터웨더] 영하권 추위에 곳곳 빙판길…주말 추위 풀려',
#  '[날씨] 퇴근길 빙판길 조심…주말 비교적 온화',
#  '"정권이 저지른 살육의 기록"…\'어떤 사람들은 죽어야 합니다\'',
#  '[오후날씨 꿀팁] 한낮 맑고 쌀쌀해, 주말 추위 풀려…빙판길·도로 살얼음 주의',
#  '알고 보면 서글픈, 두 승탑에 붙은 이름들',
#  '56세에 정년퇴임한 남편, 나도 쉬기로 했다',
#  '“부모님 앗아간 첫눈 보면 피눈물”…4명중 1명 숨지는 고관절 골절',
#  '푸틴 "미국과의 우크라 종전 관련 회동 매우 유용"',
#  '사명까지 바꿨던 메타, 4년 만에 ‘메타버스’ 구조조정 수순',
#  "'FIFA 평화상' 앞둔 트럼프, 민주콩코·르완다 평화협정 중재",
#  '日, 유엔에 \'대만 발언\' 2차 반박 서한…"中 주장 사실 아냐"',
#  '시진핑 "다자주의 실천"...마크롱 "하나의 중국 존중"',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '"일본 안가요" 中 한일령에 싱가포르에도 중국인 \'북적\' ',
#  '중국인 관광객, 태국보다 베트남 더 많이 찾는 이유는',
#  "동남아 철도는 달린다… '중국 빚 시한폭탄'을 싣고 ",
#  "'아들 낳는 약'에 '점지 기도'까지… 베트남 정부는 '딸 혜택'으로 맞불 ",
#  "넷플릭스, 워너브러더스 인수 단독 협상…엔터 업계 '지각변동' 예고",
#  "시진핑-마크롱, 몰래 만나 무슨 얘기?…청두서 '깜짝' 회동",
#  '백악관, 새 국가안보전략 공개… “한국에 국방비 증액 촉구해야”',
#  '중국, 결국 선 넘을까…“군경 함정 100여척 배치, 역대급 무력시위” [핫이슈]',
#  '“美, 韓 ‘모범동맹국’ 지칭…日은 빠질 듯”',
#  '‘300조 원’ 시리아 재건 시장 기지개…한국 기업에 ‘러브콜’ [특파원 리포트]',
#  '“대만 사람인 척하면 편해”…여권 커버 씌워 日 여행가는 중국인',
#  '中 "日군사기지화" 경계…\'난징추모일\' 무력시위 관측',
#  '우크라이나, 휴전해도 문제? "인구 축소 가속화…나라 재건할 사람이 없다 "',
#  '미 대법원, 텍사스 선거구 공화당 손들어줘···하원 최대 5석 추가 확보 전망',
#  '시진핑, 마크롱과 청두서 비공식 만남…"베이징 밖 이례적 동행"',
#  '인도, 러시아 핵잠수함 임대 합의...3조 원에 10년간 임대',
#  '"반중정서 두렵나?"…日 찾는 中여행객 사이 \'이것\' 유행',
#  '"엔비디아 H200·블랙웰 中 판매 막는다"…美상원 초당적 법안 발의',
#  '"총리 발언 철회해" 中 압박에도 日정부 "우리 입장 일관적"',
#  '中, 동아시아 해역서 함정 100척 무력시위…日 “답변 삼갈 것”',
#  '주유엔 일본대사, 다카이치 비판한 중국 서한에 “근거 부족” 재반박',
#  '금리인상 기조에 日서 10년 만에 MMF 부활한다',
#  '손정의, 美 각 곳에 ‘트럼프 산업단지’ 건설 추진',
#  '유럽, 美에 경계심…핀란드도 "美, 우크라 협상 동안에도 러 접촉"(종합)',
#  '"일본 안가요" 中 한일령에 싱가포르에도 중국인 \'북적\' [아세안 속으로]',
#  '"중국에 팔게 해 줘" 젠슨 황 로비에도…의회는 \'NO\'',
#  '미, 전쟁범죄 논란에도 마약 밀수 의심 선박 폭격 재개',
#  '불붙은 워너 인수전 "넷플 최고가"…파라마운트는 \'불공정\' 항의',
#  "1명 태어날 때 3명 죽는다…우크라 패전보다 두려운 '인구붕괴 쇼크'",
#  '"규제만 1만 8000개…美 제조업 부활 가능할까"',
#  '다카이치 어쩌나…“한국을 ‘모범 동맹국’으로 지정한 트럼프, 일본은 제외” 이유는? [핫이슈]',
#  '"시대 변했다, 말장난 안 통해"…中관영지들, 전문가 통해 日비난',
#  '소프트뱅크 손정의, 美 각 곳에 ‘트럼프 산업단지’ 건설 추진',
#  "中, '1억대 극초음속 미사일, 40시간 드론'으로 美·日 견제 [HK영상]",
#  '239명 태운 비행기가 흔적도 없이 사라졌다…마지막 교신은 “굿나잇”',
#  '부자 2919명 총자산 ‘2경3000조원’, 한국 예산 31년분···억만장자 287명 늘었다',
#  '“젠슨 황은 무기상” 비판 나오더니…美상원, 엔비디아 첨단 칩 中수출 제동',
#  '월드컵을 무역 협상장으로? 트럼프, 조추첨 직전 加·멕시코 압박 재개',
#  "[트럼프 스톡커] 中이 앞선 로봇, '제조업 허약' 美 이길 수 있나",
#  '인도, 약 3조원에 러시아 핵잠수함 10년간 임대 합의']

# %%
len(article_list), article_list[:30]
# Out:
# (197,
#  ['신한라이프 신임사장 후보에 천상영 신한지주 부사장',
#   '3분기 은행권 보통주자본비율 소폭 하락…“환율 영향 불확실성, 추가 모니터링”',
#   'HD현대 “2030년 매출 100조 달성 목표”',
#   '한미약품 ‘한국인 맞춤형 비만약’, 식약처 신속심사 지정',
#   '구윤철 “고환율 해결책은 국가·기업 경쟁력 제고”',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '리브스메드 "글로벌 수술 로봇 시장 리더십 장악할 것"',
#   '\'일라이릴리 픽\' 알지노믹스 "유전자치료제 선도기업 될 것"',
#   '\'초소형 위성\' 나라스페이스 "뉴 스페이스 시대 선도"',
#   '\'미세바늘업체\' 쿼드메디슨 "약물전달 패러다임 전환 선도"',
#   '해당 정보 없음',
#   '해당 정보 없음',
#   '美 정부 “AI 다음은 로봇” 점찍자…韓 기업도 웃는다',
#   '기아 80주년…정의선 “기아의 미래는 도전”',
#   "기아 창립 80주년⋯'비전 메타투리스모' 최초 공개",
#   '반도체 호조에 뇌수술로봇까지…2주만에 주가 53% 뜬 고영',
#   '키움운용, S&P500 승자만 고르는 ‘한국판 SPMO’ ETF 9일 신규 상장',
#   "개인정보 싹 털린 쿠팡, 이용자 수 18만명 '뚝'…대규모 이탈 본격화 조짐",
#   '올 겨울 최대전력수요, 88.8∼94.5GW 예상…기후부, 첫 전력 수급 대책',
#   "미래·KB·카카오 'AI 혁신금융 서비스' 발 뺐다",
#   'SK·에이치라인해운 본사 부산행…"해양수도권 조성의 화룡점정"(종합)',
#   "철강 불황이라더니...'KRX 철강' 지수 상승률 상위권, 이유는",
#   '"트럼프가 힘 실어주나"…훨훨 날아오른 로봇주',
#   '李 \'AI 기본사회\' 구상…손정의 "다음은 초인공지능"',
#   '이탈 본격화하나…쿠팡 이용자, 나흘 만에 줄었다',
#   'DS증권 "현대차그룹, 日토요타와 닮은꼴 지배구조 리레이팅에 주목"'])

# %%
import threading
import pandas as pd
df = pd.DataFrame(columns=["category","title"])

# %%
def get_article(page):
    #driver = webdriver.Chrome("C:/Myexam/chromedriver/chromedriver.exe")
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    driver.get("https://news.naver.com/section/10" + str(page))
    category = driver.find_element(By.CSS_SELECTOR, '.ct_snb_h2_a').get_attribute("innerText")
    articles = driver.find_elements(By.CSS_SELECTOR,'#newsct li')
    for article in articles:
        try:
            tmp_elements = article.find_elements(By.CSS_SELECTOR, '.sa_text strong')
            if tmp_elements:
                title = tmp_elements[0].text
            else:
                tmp_elements2 = article.find_elements(By.CSS_SELECTOR, '.ss_text a')
                if tmp_elements2:
                    title = tmp_elements2[0].text
                else:
                    title = "해당 정보 없음"
        except:
            print("에러 발생!")
        df.loc[len(df)] = {
            "category": category,
            "title": title,
        }
    print("end :", page+1)
    # driver.quit()

# %%
# %%time
for page in range(0, 6):
    get_article(page)
# Out:
# end : 1
# end : 2
# end : 3
# end : 4
# end : 5
# end : 6
# CPU times: user 439 ms, sys: 239 ms, total: 678 ms
# Wall time: 14.9 s

# %%
df
# Out:
#     category                                         title
# 0         정치                     대통령실, '인사청탁' 논란 김남국 사의 수용
# 1         정치               장경태 ‘성추행 의혹’ 확산… 민주당은 ‘제식구 감싸기’
# 2         정치                 법원, 정청래 대표 ‘1인 1표제’ 무효 가처분 기각
# 3         정치             박지원 "형, 누나 부르는 건 민주당 풍토…김남국은 일벌레"
# 4         정치           합참의장, 수도권 방어부대 현장점검 "수도서울 철통 방어” 강조
# ..       ...                                           ...
# 296    IT/과학           초 인공지능 화두 꺼낸 손정의…이 대통령 'AI 기본사회' 천명
# 297    IT/과학               MZ세대-중장년층 'AI 세대격차' 심화…무엇이 다를까?
# 298    IT/과학  "민간은 수백억 투입, 정부는 방치"…국정자원 화재가 드러낸 현실 [클라우드+]
# 299    IT/과학      “사명까지 바꿨는데”… 메타, 4년 만에 ‘메타버스’ 사업 구조조정 착수
# 300    IT/과학              아프리카 에이즈 고질병 왜…"근본적 시스템 따져야 할 때"
#
# [301 rows x 2 columns]

# %%
df['category'].value_counts()
# Out:
# category
# 경제       52
# IT/과학    52
# 정치       50
# 사회       50
# 세계       50
# 생활/문화    47
# Name: count, dtype: int64
