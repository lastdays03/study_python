# %%
x = 95
if x >= 90:
    print("Pass")
# Out:
# Pass

# %%
x = 75
if x >= 90:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
x = 85
if x >= 90:
    print("Very Good")
elif 80 <= x < 90:
    print("Good")
else:
    print("Bad")
# Out:
# Good

# %%
x = 100
if x >= 90:
    if x == 100:
        print("Perfect")
    else:
        print("Very Good")
elif 80 <= x < 90:
    print("Good")
else:
    print("Bad")
# Out:
# Perfect
